# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, Dense

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=64,
    image_size=(227,227),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 42297 files belonging to 39 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=64,
    image_size=(227,227),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 4713 files belonging to 39 classes.

# %%
def build_efficientnet_b0(input_shape=(227, 227, 3), num_classes=38):
    inputs = tf.keras.Input(shape=input_shape)
    
    # Stem
    x = Conv2D(32, 3, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Blocks
    x = efficientnet_block(x, 1, 16, 1, 1)
    x = efficientnet_block(x, 6, 24, 2, 2)  # MBConv1
    x = efficientnet_block(x, 6, 40, 2, 2)  # MBConv2
    x = efficientnet_block(x, 6, 80, 3, 2)  # MBConv3
    x = efficientnet_block(x, 6, 112, 3, 1) # MBConv4
    x = efficientnet_block(x, 6, 192, 4, 2) # MBConv5
    x = efficientnet_block(x, 6, 320, 1, 1) # MBConv6

    # Head
    x = Conv2D(1280, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    # Output
    outputs = Dense(39, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model

def efficientnet_block(inputs, num_repeat, out_channels, expand_ratio, strides):
    x = mb_conv_block(inputs, out_channels, expand_ratio, strides)
    for _ in range(1, num_repeat):
        x = mb_conv_block(x, out_channels, expand_ratio, 1)
    return x

def mb_conv_block(inputs, out_channels, expand_ratio, strides):
    input_channels = inputs.shape[-1]

    # Expansion phase
    expanded_channels = input_channels * expand_ratio
    x = Conv2D(expanded_channels, 1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    # Depthwise convolution
    x = Conv2D(expanded_channels, 3, strides=strides, padding='same', groups=expanded_channels)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    # Projection phase
    x = Conv2D(out_channels, 1, padding='same')(x)
    x = BatchNormalization()(x)

    # Skip connection if the input and output shapes are the same (identity)
    if strides == 1 and input_channels == out_channels:
        x = tf.keras.layers.Add()([inputs, x])
    return x

# Build EfficientNetB0
model = build_efficientnet_b0()

# %%
model.compile(optimizer=tf.keras.optimizers.legacy.Adam(
    learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 227, 227, 3)]        0         []
#
#  conv2d_226 (Conv2D)         (None, 114, 114, 32)         896       ['input_4[0][0]']
#
#  batch_normalization_226 (B  (None, 114, 114, 32)         128       ['conv2d_226[0][0]']
#  atchNormalization)
#
#  activation_152 (Activation  (None, 114, 114, 32)         0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  conv2d_227 (Conv2D)         (None, 114, 114, 32)         1056      ['activation_152[0][0]']
#
#  batch_normalization_227 (B  (None, 114, 114, 32)         128       ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_153 (Activation  (None, 114, 114, 32)         0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv2d_228 (Conv2D)         (None, 114, 114, 32)         320       ['activation_153[0][0]']
#
#  batch_normalization_228 (B  (None, 114, 114, 32)         128       ['conv2d_228[0][0]']
#  atchNormalization)
#
#  activation_154 (Activation  (None, 114, 114, 32)         0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  conv2d_229 (Conv2D)         (None, 114, 114, 16)         528       ['activation_154[0][0]']
#
#  batch_normalization_229 (B  (None, 114, 114, 16)         64        ['conv2d_229[0][0]']
#  atchNormalization)
#
#  conv2d_230 (Conv2D)         (None, 114, 114, 32)         544       ['batch_normalization_229[0][0
#                                                                     ]']
#
#  batch_normalization_230 (B  (None, 114, 114, 32)         128       ['conv2d_230[0][0]']
#  atchNormalization)
#
#  activation_155 (Activation  (None, 114, 114, 32)         0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  conv2d_231 (Conv2D)         (None, 57, 57, 32)           320       ['activation_155[0][0]']
#
#  batch_normalization_231 (B  (None, 57, 57, 32)           128       ['conv2d_231[0][0]']
#  atchNormalization)
#
#  activation_156 (Activation  (None, 57, 57, 32)           0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  conv2d_232 (Conv2D)         (None, 57, 57, 24)           792       ['activation_156[0][0]']
#
#  batch_normalization_232 (B  (None, 57, 57, 24)           96        ['conv2d_232[0][0]']
#  atchNormalization)
#
#  conv2d_233 (Conv2D)         (None, 57, 57, 48)           1200      ['batch_normalization_232[0][0
#                                                                     ]']
#
#  batch_normalization_233 (B  (None, 57, 57, 48)           192       ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_157 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_234 (Conv2D)         (None, 57, 57, 48)           480       ['activation_157[0][0]']
#
#  batch_normalization_234 (B  (None, 57, 57, 48)           192       ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_158 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_235 (Conv2D)         (None, 57, 57, 24)           1176      ['activation_158[0][0]']
#
#  batch_normalization_235 (B  (None, 57, 57, 24)           96        ['conv2d_235[0][0]']
#  atchNormalization)
#
#  add_60 (Add)                (None, 57, 57, 24)           0         ['batch_normalization_232[0][0
#                                                                     ]',
#                                                                      'batch_normalization_235[0][0
#                                                                     ]']
#
#  conv2d_236 (Conv2D)         (None, 57, 57, 48)           1200      ['add_60[0][0]']
#
#  batch_normalization_236 (B  (None, 57, 57, 48)           192       ['conv2d_236[0][0]']
#  atchNormalization)
#
#  activation_159 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  conv2d_237 (Conv2D)         (None, 57, 57, 48)           480       ['activation_159[0][0]']
#
#  batch_normalization_237 (B  (None, 57, 57, 48)           192       ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_160 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv2d_238 (Conv2D)         (None, 57, 57, 24)           1176      ['activation_160[0][0]']
#
#  batch_normalization_238 (B  (None, 57, 57, 24)           96        ['conv2d_238[0][0]']
#  atchNormalization)
#
#  add_61 (Add)                (None, 57, 57, 24)           0         ['add_60[0][0]',
#                                                                      'batch_normalization_238[0][0
#                                                                     ]']
#
#  conv2d_239 (Conv2D)         (None, 57, 57, 48)           1200      ['add_61[0][0]']
#
#  batch_normalization_239 (B  (None, 57, 57, 48)           192       ['conv2d_239[0][0]']
#  atchNormalization)
#
#  activation_161 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_239[0][0
#  )                                                                  ]']
#
#  conv2d_240 (Conv2D)         (None, 57, 57, 48)           480       ['activation_161[0][0]']
#
#  batch_normalization_240 (B  (None, 57, 57, 48)           192       ['conv2d_240[0][0]']
#  atchNormalization)
#
#  activation_162 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  conv2d_241 (Conv2D)         (None, 57, 57, 24)           1176      ['activation_162[0][0]']
#
#  batch_normalization_241 (B  (None, 57, 57, 24)           96        ['conv2d_241[0][0]']
#  atchNormalization)
#
#  add_62 (Add)                (None, 57, 57, 24)           0         ['add_61[0][0]',
#                                                                      'batch_normalization_241[0][0
#                                                                     ]']
#
#  conv2d_242 (Conv2D)         (None, 57, 57, 48)           1200      ['add_62[0][0]']
#
#  batch_normalization_242 (B  (None, 57, 57, 48)           192       ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_163 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 57, 57, 48)           480       ['activation_163[0][0]']
#
#  batch_normalization_243 (B  (None, 57, 57, 48)           192       ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_164 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_244 (Conv2D)         (None, 57, 57, 24)           1176      ['activation_164[0][0]']
#
#  batch_normalization_244 (B  (None, 57, 57, 24)           96        ['conv2d_244[0][0]']
#  atchNormalization)
#
#  add_63 (Add)                (None, 57, 57, 24)           0         ['add_62[0][0]',
#                                                                      'batch_normalization_244[0][0
#                                                                     ]']
#
#  conv2d_245 (Conv2D)         (None, 57, 57, 48)           1200      ['add_63[0][0]']
#
#  batch_normalization_245 (B  (None, 57, 57, 48)           192       ['conv2d_245[0][0]']
#  atchNormalization)
#
#  activation_165 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_245[0][0
#  )                                                                  ]']
#
#  conv2d_246 (Conv2D)         (None, 57, 57, 48)           480       ['activation_165[0][0]']
#
#  batch_normalization_246 (B  (None, 57, 57, 48)           192       ['conv2d_246[0][0]']
#  atchNormalization)
#
#  activation_166 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  conv2d_247 (Conv2D)         (None, 57, 57, 24)           1176      ['activation_166[0][0]']
#
#  batch_normalization_247 (B  (None, 57, 57, 24)           96        ['conv2d_247[0][0]']
#  atchNormalization)
#
#  add_64 (Add)                (None, 57, 57, 24)           0         ['add_63[0][0]',
#                                                                      'batch_normalization_247[0][0
#                                                                     ]']
#
#  conv2d_248 (Conv2D)         (None, 57, 57, 48)           1200      ['add_64[0][0]']
#
#  batch_normalization_248 (B  (None, 57, 57, 48)           192       ['conv2d_248[0][0]']
#  atchNormalization)
#
#  activation_167 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_248[0][0
#  )                                                                  ]']
#
#  conv2d_249 (Conv2D)         (None, 29, 29, 48)           480       ['activation_167[0][0]']
#
#  batch_normalization_249 (B  (None, 29, 29, 48)           192       ['conv2d_249[0][0]']
#  atchNormalization)
#
#  activation_168 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_249[0][0
#  )                                                                  ]']
#
#  conv2d_250 (Conv2D)         (None, 29, 29, 40)           1960      ['activation_168[0][0]']
#
#  batch_normalization_250 (B  (None, 29, 29, 40)           160       ['conv2d_250[0][0]']
#  atchNormalization)
#
#  conv2d_251 (Conv2D)         (None, 29, 29, 80)           3280      ['batch_normalization_250[0][0
#                                                                     ]']
#
#  batch_normalization_251 (B  (None, 29, 29, 80)           320       ['conv2d_251[0][0]']
#  atchNormalization)
#
#  activation_169 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_251[0][0
#  )                                                                  ]']
#
#  conv2d_252 (Conv2D)         (None, 29, 29, 80)           800       ['activation_169[0][0]']
#
#  batch_normalization_252 (B  (None, 29, 29, 80)           320       ['conv2d_252[0][0]']
#  atchNormalization)
#
#  activation_170 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_252[0][0
#  )                                                                  ]']
#
#  conv2d_253 (Conv2D)         (None, 29, 29, 40)           3240      ['activation_170[0][0]']
#
#  batch_normalization_253 (B  (None, 29, 29, 40)           160       ['conv2d_253[0][0]']
#  atchNormalization)
#
#  add_65 (Add)                (None, 29, 29, 40)           0         ['batch_normalization_250[0][0
#                                                                     ]',
#                                                                      'batch_normalization_253[0][0
#                                                                     ]']
#
#  conv2d_254 (Conv2D)         (None, 29, 29, 80)           3280      ['add_65[0][0]']
#
#  batch_normalization_254 (B  (None, 29, 29, 80)           320       ['conv2d_254[0][0]']
#  atchNormalization)
#
#  activation_171 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_254[0][0
#  )                                                                  ]']
#
#  conv2d_255 (Conv2D)         (None, 29, 29, 80)           800       ['activation_171[0][0]']
#
#  batch_normalization_255 (B  (None, 29, 29, 80)           320       ['conv2d_255[0][0]']
#  atchNormalization)
#
#  activation_172 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_255[0][0
#  )                                                                  ]']
#
#  conv2d_256 (Conv2D)         (None, 29, 29, 40)           3240      ['activation_172[0][0]']
#
#  batch_normalization_256 (B  (None, 29, 29, 40)           160       ['conv2d_256[0][0]']
#  atchNormalization)
#
#  add_66 (Add)                (None, 29, 29, 40)           0         ['add_65[0][0]',
#                                                                      'batch_normalization_256[0][0
#                                                                     ]']
#
#  conv2d_257 (Conv2D)         (None, 29, 29, 80)           3280      ['add_66[0][0]']
#
#  batch_normalization_257 (B  (None, 29, 29, 80)           320       ['conv2d_257[0][0]']
#  atchNormalization)
#
#  activation_173 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_257[0][0
#  )                                                                  ]']
#
#  conv2d_258 (Conv2D)         (None, 29, 29, 80)           800       ['activation_173[0][0]']
#
#  batch_normalization_258 (B  (None, 29, 29, 80)           320       ['conv2d_258[0][0]']
#  atchNormalization)
#
#  activation_174 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_258[0][0
#  )                                                                  ]']
#
#  conv2d_259 (Conv2D)         (None, 29, 29, 40)           3240      ['activation_174[0][0]']
#
#  batch_normalization_259 (B  (None, 29, 29, 40)           160       ['conv2d_259[0][0]']
#  atchNormalization)
#
#  add_67 (Add)                (None, 29, 29, 40)           0         ['add_66[0][0]',
#                                                                      'batch_normalization_259[0][0
#                                                                     ]']
#
#  conv2d_260 (Conv2D)         (None, 29, 29, 80)           3280      ['add_67[0][0]']
#
#  batch_normalization_260 (B  (None, 29, 29, 80)           320       ['conv2d_260[0][0]']
#  atchNormalization)
#
#  activation_175 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_260[0][0
#  )                                                                  ]']
#
#  conv2d_261 (Conv2D)         (None, 29, 29, 80)           800       ['activation_175[0][0]']
#
#  batch_normalization_261 (B  (None, 29, 29, 80)           320       ['conv2d_261[0][0]']
#  atchNormalization)
#
#  activation_176 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_261[0][0
#  )                                                                  ]']
#
#  conv2d_262 (Conv2D)         (None, 29, 29, 40)           3240      ['activation_176[0][0]']
#
#  batch_normalization_262 (B  (None, 29, 29, 40)           160       ['conv2d_262[0][0]']
#  atchNormalization)
#
#  add_68 (Add)                (None, 29, 29, 40)           0         ['add_67[0][0]',
#                                                                      'batch_normalization_262[0][0
#                                                                     ]']
#
#  conv2d_263 (Conv2D)         (None, 29, 29, 80)           3280      ['add_68[0][0]']
#
#  batch_normalization_263 (B  (None, 29, 29, 80)           320       ['conv2d_263[0][0]']
#  atchNormalization)
#
#  activation_177 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_263[0][0
#  )                                                                  ]']
#
#  conv2d_264 (Conv2D)         (None, 29, 29, 80)           800       ['activation_177[0][0]']
#
#  batch_normalization_264 (B  (None, 29, 29, 80)           320       ['conv2d_264[0][0]']
#  atchNormalization)
#
#  activation_178 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_264[0][0
#  )                                                                  ]']
#
#  conv2d_265 (Conv2D)         (None, 29, 29, 40)           3240      ['activation_178[0][0]']
#
#  batch_normalization_265 (B  (None, 29, 29, 40)           160       ['conv2d_265[0][0]']
#  atchNormalization)
#
#  add_69 (Add)                (None, 29, 29, 40)           0         ['add_68[0][0]',
#                                                                      'batch_normalization_265[0][0
#                                                                     ]']
#
#  conv2d_266 (Conv2D)         (None, 29, 29, 120)          4920      ['add_69[0][0]']
#
#  batch_normalization_266 (B  (None, 29, 29, 120)          480       ['conv2d_266[0][0]']
#  atchNormalization)
#
#  activation_179 (Activation  (None, 29, 29, 120)          0         ['batch_normalization_266[0][0
#  )                                                                  ]']
#
#  conv2d_267 (Conv2D)         (None, 15, 15, 120)          1200      ['activation_179[0][0]']
#
#  batch_normalization_267 (B  (None, 15, 15, 120)          480       ['conv2d_267[0][0]']
#  atchNormalization)
#
#  activation_180 (Activation  (None, 15, 15, 120)          0         ['batch_normalization_267[0][0
#  )                                                                  ]']
#
#  conv2d_268 (Conv2D)         (None, 15, 15, 80)           9680      ['activation_180[0][0]']
#
#  batch_normalization_268 (B  (None, 15, 15, 80)           320       ['conv2d_268[0][0]']
#  atchNormalization)
#
#  conv2d_269 (Conv2D)         (None, 15, 15, 240)          19440     ['batch_normalization_268[0][0
#                                                                     ]']
#
#  batch_normalization_269 (B  (None, 15, 15, 240)          960       ['conv2d_269[0][0]']
#  atchNormalization)
#
#  activation_181 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_269[0][0
#  )                                                                  ]']
#
#  conv2d_270 (Conv2D)         (None, 15, 15, 240)          2400      ['activation_181[0][0]']
#
#  batch_normalization_270 (B  (None, 15, 15, 240)          960       ['conv2d_270[0][0]']
#  atchNormalization)
#
#  activation_182 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_270[0][0
#  )                                                                  ]']
#
#  conv2d_271 (Conv2D)         (None, 15, 15, 80)           19280     ['activation_182[0][0]']
#
#  batch_normalization_271 (B  (None, 15, 15, 80)           320       ['conv2d_271[0][0]']
#  atchNormalization)
#
#  add_70 (Add)                (None, 15, 15, 80)           0         ['batch_normalization_268[0][0
#                                                                     ]',
#                                                                      'batch_normalization_271[0][0
#                                                                     ]']
#
#  conv2d_272 (Conv2D)         (None, 15, 15, 240)          19440     ['add_70[0][0]']
#
#  batch_normalization_272 (B  (None, 15, 15, 240)          960       ['conv2d_272[0][0]']
#  atchNormalization)
#
#  activation_183 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_272[0][0
#  )                                                                  ]']
#
#  conv2d_273 (Conv2D)         (None, 15, 15, 240)          2400      ['activation_183[0][0]']
#
#  batch_normalization_273 (B  (None, 15, 15, 240)          960       ['conv2d_273[0][0]']
#  atchNormalization)
#
#  activation_184 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_273[0][0
#  )                                                                  ]']
#
#  conv2d_274 (Conv2D)         (None, 15, 15, 80)           19280     ['activation_184[0][0]']
#
#  batch_normalization_274 (B  (None, 15, 15, 80)           320       ['conv2d_274[0][0]']
#  atchNormalization)
#
#  add_71 (Add)                (None, 15, 15, 80)           0         ['add_70[0][0]',
#                                                                      'batch_normalization_274[0][0
#                                                                     ]']
#
#  conv2d_275 (Conv2D)         (None, 15, 15, 240)          19440     ['add_71[0][0]']
#
#  batch_normalization_275 (B  (None, 15, 15, 240)          960       ['conv2d_275[0][0]']
#  atchNormalization)
#
#  activation_185 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_275[0][0
#  )                                                                  ]']
#
#  conv2d_276 (Conv2D)         (None, 15, 15, 240)          2400      ['activation_185[0][0]']
#
#  batch_normalization_276 (B  (None, 15, 15, 240)          960       ['conv2d_276[0][0]']
#  atchNormalization)
#
#  activation_186 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_276[0][0
#  )                                                                  ]']
#
#  conv2d_277 (Conv2D)         (None, 15, 15, 80)           19280     ['activation_186[0][0]']
#
#  batch_normalization_277 (B  (None, 15, 15, 80)           320       ['conv2d_277[0][0]']
#  atchNormalization)
#
#  add_72 (Add)                (None, 15, 15, 80)           0         ['add_71[0][0]',
#                                                                      'batch_normalization_277[0][0
#                                                                     ]']
#
#  conv2d_278 (Conv2D)         (None, 15, 15, 240)          19440     ['add_72[0][0]']
#
#  batch_normalization_278 (B  (None, 15, 15, 240)          960       ['conv2d_278[0][0]']
#  atchNormalization)
#
#  activation_187 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_278[0][0
#  )                                                                  ]']
#
#  conv2d_279 (Conv2D)         (None, 15, 15, 240)          2400      ['activation_187[0][0]']
#
#  batch_normalization_279 (B  (None, 15, 15, 240)          960       ['conv2d_279[0][0]']
#  atchNormalization)
#
#  activation_188 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_279[0][0
#  )                                                                  ]']
#
#  conv2d_280 (Conv2D)         (None, 15, 15, 80)           19280     ['activation_188[0][0]']
#
#  batch_normalization_280 (B  (None, 15, 15, 80)           320       ['conv2d_280[0][0]']
#  atchNormalization)
#
#  add_73 (Add)                (None, 15, 15, 80)           0         ['add_72[0][0]',
#                                                                      'batch_normalization_280[0][0
#                                                                     ]']
#
#  conv2d_281 (Conv2D)         (None, 15, 15, 240)          19440     ['add_73[0][0]']
#
#  batch_normalization_281 (B  (None, 15, 15, 240)          960       ['conv2d_281[0][0]']
#  atchNormalization)
#
#  activation_189 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_281[0][0
#  )                                                                  ]']
#
#  conv2d_282 (Conv2D)         (None, 15, 15, 240)          2400      ['activation_189[0][0]']
#
#  batch_normalization_282 (B  (None, 15, 15, 240)          960       ['conv2d_282[0][0]']
#  atchNormalization)
#
#  activation_190 (Activation  (None, 15, 15, 240)          0         ['batch_normalization_282[0][0
#  )                                                                  ]']
#
#  conv2d_283 (Conv2D)         (None, 15, 15, 80)           19280     ['activation_190[0][0]']
#
#  batch_normalization_283 (B  (None, 15, 15, 80)           320       ['conv2d_283[0][0]']
#  atchNormalization)
#
#  add_74 (Add)                (None, 15, 15, 80)           0         ['add_73[0][0]',
#                                                                      'batch_normalization_283[0][0
#                                                                     ]']
#
#  conv2d_284 (Conv2D)         (None, 15, 15, 240)          19440     ['add_74[0][0]']
#
#  batch_normalization_284 (B  (None, 15, 15, 240)          960       ['conv2d_284[0][0]']
#  atchNormalization)
#
# ...
#
#  activation_215 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_320[0][0
#  )                                                                  ]']
#
#  conv2d_321 (Conv2D)         (None, 8, 8, 192)            1920      ['activation_215[0][0]']
#
#  batch_normalization_321 (B  (None, 8, 8, 192)            768       ['conv2d_321[0][0]']
#  atchNormalization)
#
#  activation_216 (Activation  (None, 8, 8, 192)            0         ['batch_normalization_321[0][0
#  )                                                                  ]']
#
#  conv2d_322 (Conv2D)         (None, 8, 8, 320)            61760     ['activation_216[0][0]']
#
#  batch_normalization_322 (B  (None, 8, 8, 320)            1280      ['conv2d_322[0][0]']
#  atchNormalization)
#
#  conv2d_323 (Conv2D)         (None, 8, 8, 320)            102720    ['batch_normalization_322[0][0
#                                                                     ]']
#
#  batch_normalization_323 (B  (None, 8, 8, 320)            1280      ['conv2d_323[0][0]']
#  atchNormalization)
#
#  activation_217 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_323[0][0
#  )                                                                  ]']
#
#  conv2d_324 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_217[0][0]']
#
#  batch_normalization_324 (B  (None, 8, 8, 320)            1280      ['conv2d_324[0][0]']
#  atchNormalization)
#
#  activation_218 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_324[0][0
#  )                                                                  ]']
#
#  conv2d_325 (Conv2D)         (None, 8, 8, 320)            102720    ['activation_218[0][0]']
#
#  batch_normalization_325 (B  (None, 8, 8, 320)            1280      ['conv2d_325[0][0]']
#  atchNormalization)
#
#  add_85 (Add)                (None, 8, 8, 320)            0         ['batch_normalization_322[0][0
#                                                                     ]',
#                                                                      'batch_normalization_325[0][0
#                                                                     ]']
#
#  conv2d_326 (Conv2D)         (None, 8, 8, 320)            102720    ['add_85[0][0]']
#
#  batch_normalization_326 (B  (None, 8, 8, 320)            1280      ['conv2d_326[0][0]']
#  atchNormalization)
#
#  activation_219 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_326[0][0
#  )                                                                  ]']
#
#  conv2d_327 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_219[0][0]']
#
#  batch_normalization_327 (B  (None, 8, 8, 320)            1280      ['conv2d_327[0][0]']
#  atchNormalization)
#
#  activation_220 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_327[0][0
#  )                                                                  ]']
#
#  conv2d_328 (Conv2D)         (None, 8, 8, 320)            102720    ['activation_220[0][0]']
#
#  batch_normalization_328 (B  (None, 8, 8, 320)            1280      ['conv2d_328[0][0]']
#  atchNormalization)
#
#  add_86 (Add)                (None, 8, 8, 320)            0         ['add_85[0][0]',
#                                                                      'batch_normalization_328[0][0
#                                                                     ]']
#
#  conv2d_329 (Conv2D)         (None, 8, 8, 320)            102720    ['add_86[0][0]']
#
#  batch_normalization_329 (B  (None, 8, 8, 320)            1280      ['conv2d_329[0][0]']
#  atchNormalization)
#
#  activation_221 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_329[0][0
#  )                                                                  ]']
#
#  conv2d_330 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_221[0][0]']
#
#  batch_normalization_330 (B  (None, 8, 8, 320)            1280      ['conv2d_330[0][0]']
#  atchNormalization)
#
#  activation_222 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_330[0][0
#  )                                                                  ]']
#
#  conv2d_331 (Conv2D)         (None, 8, 8, 320)            102720    ['activation_222[0][0]']
#
#  batch_normalization_331 (B  (None, 8, 8, 320)            1280      ['conv2d_331[0][0]']
#  atchNormalization)
#
#  add_87 (Add)                (None, 8, 8, 320)            0         ['add_86[0][0]',
#                                                                      'batch_normalization_331[0][0
#                                                                     ]']
#
#  conv2d_332 (Conv2D)         (None, 8, 8, 320)            102720    ['add_87[0][0]']
#
#  batch_normalization_332 (B  (None, 8, 8, 320)            1280      ['conv2d_332[0][0]']
#  atchNormalization)
#
#  activation_223 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_332[0][0
#  )                                                                  ]']
#
#  conv2d_333 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_223[0][0]']
#
#  batch_normalization_333 (B  (None, 8, 8, 320)            1280      ['conv2d_333[0][0]']
#  atchNormalization)
#
#  activation_224 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_333[0][0
#  )                                                                  ]']
#
#  conv2d_334 (Conv2D)         (None, 8, 8, 320)            102720    ['activation_224[0][0]']
#
#  batch_normalization_334 (B  (None, 8, 8, 320)            1280      ['conv2d_334[0][0]']
#  atchNormalization)
#
#  add_88 (Add)                (None, 8, 8, 320)            0         ['add_87[0][0]',
#                                                                      'batch_normalization_334[0][0
#                                                                     ]']
#
#  conv2d_335 (Conv2D)         (None, 8, 8, 320)            102720    ['add_88[0][0]']
#
#  batch_normalization_335 (B  (None, 8, 8, 320)            1280      ['conv2d_335[0][0]']
#  atchNormalization)
#
#  activation_225 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_335[0][0
#  )                                                                  ]']
#
#  conv2d_336 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_225[0][0]']
#
#  batch_normalization_336 (B  (None, 8, 8, 320)            1280      ['conv2d_336[0][0]']
#  atchNormalization)
#
#  activation_226 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_336[0][0
#  )                                                                  ]']
#
#  conv2d_337 (Conv2D)         (None, 8, 8, 320)            102720    ['activation_226[0][0]']
#
#  batch_normalization_337 (B  (None, 8, 8, 320)            1280      ['conv2d_337[0][0]']
#  atchNormalization)
#
#  add_89 (Add)                (None, 8, 8, 320)            0         ['add_88[0][0]',
#                                                                      'batch_normalization_337[0][0
#                                                                     ]']
#
#  conv2d_338 (Conv2D)         (None, 8, 8, 1280)           410880    ['add_89[0][0]']
#
#  batch_normalization_338 (B  (None, 8, 8, 1280)           5120      ['conv2d_338[0][0]']
#  atchNormalization)
#
#  activation_227 (Activation  (None, 8, 8, 1280)           0         ['batch_normalization_338[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_2  (None, 1280)                 0         ['activation_227[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 39)                   49959     ['global_average_pooling2d_2[0
#                                                                     ][0]']
#
# ==================================================================================================
# Total params: 4092735 (15.61 MB)
# Trainable params: 4040575 (15.41 MB)
# Non-trainable params: 52160 (203.75 KB)
# __________________________________________________________________________________________________

# %%
training_history = model.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 2024-05-02 01:11:14.681612: I external/local_xla/xla/service/service.cc:168] XLA service 0x29d70d380 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-05-02 01:11:14.681813: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714592474.808267       1 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-05-02 01:11:14.808994: E external/local_xla/xla/stream_executor/stream_executor_internal.h:177] SetPriority unimplemented for this stream.
#   1/661 [..............................] - ETA: 5:44:52 - loss: 3.8439 - accuracy: 0.0000e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 training_history = model.fit(x=training_set,validation_data=validation_set,epochs=10)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#Training set Accuracy
train_loss, train_acc = model.evaluate(training_set)
print('Training accuracy:', train_acc)

#Validation set Accuracy
val_loss, val_acc = model.evaluate(validation_set)
print('Validation accuracy:', val_acc)

model.save('efficientnet.keras')
