# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
from tensorflow.keras.layers import Lambda,Multiply,Reshape,Multiply,Concatenate,Conv2D, BatchNormalization, Activation, MaxPooling2D, GlobalAveragePooling2D, GlobalMaxPooling2D,Dense,GlobalMaxPooling2D

# %%
training_set = tf.keras.utils.image_dataset_from_directory(
    'train',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=64,
    image_size=(227,227),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 42297 files belonging to 39 classes.

# %%
validation_set = tf.keras.utils.image_dataset_from_directory(
    'valid',
    labels="inferred",
    label_mode="categorical",
    class_names=None,
    color_mode="rgb",
    batch_size=64,
    image_size=(227,227),
    shuffle=True,
    seed=None,
    validation_split=None,
    subset=None,
    interpolation="bilinear",
    follow_links=False,
    crop_to_aspect_ratio=False
)
# Out:
# Found 4713 files belonging to 39 classes.

# %%
def build_efficientnet_b0_cbam(input_shape=(227, 227, 3), num_classes=38):
    inputs = tf.keras.Input(shape=input_shape)
    
    # Stem
    x = Conv2D(32, 3, strides=2, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Blocks
    x = efficientnet_block_cbam(x, 1, 16, 1, 1)
    x = efficientnet_block_cbam(x, 6, 24, 2, 2)  # MBConv1
    x = efficientnet_block_cbam(x, 6, 40, 2, 2)  # MBConv2
    x = efficientnet_block_cbam(x, 6, 80, 3, 2)  # MBConv3
    x = efficientnet_block_cbam(x, 6, 112, 3, 1) # MBConv4
    x = efficientnet_block_cbam(x, 6, 192, 4, 2) # MBConv5
    x = efficientnet_block_cbam(x, 6, 320, 1, 1) # MBConv6

    # Head
    x = Conv2D(1280, 1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = GlobalAveragePooling2D()(x)

    # Output
    outputs = Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs, outputs)
    return model

def efficientnet_block_cbam(inputs, num_repeat, out_channels, expand_ratio, strides):
    x = mb_conv_block_cbam(inputs, out_channels, expand_ratio, strides)
    for _ in range(1, num_repeat):
        x = mb_conv_block_cbam(x, out_channels, expand_ratio, 1)
    return x

def mb_conv_block_cbam(inputs, out_channels, expand_ratio, strides):
    input_channels = inputs.shape[-1]

    # Expansion phase
    expanded_channels = input_channels * expand_ratio
    x = Conv2D(expanded_channels, 1, padding='same')(inputs)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    # Depthwise convolution
    x = Conv2D(expanded_channels, 3, strides=strides, padding='same', groups=expanded_channels)(x)
    x = BatchNormalization()(x)
    x = Activation('swish')(x)

    # CBAM module
    x = cbam_block(x)

    # Projection phase
    x = Conv2D(out_channels, 1, padding='same')(x)
    x = BatchNormalization()(x)

    # Skip connection if the input and output shapes are the same (identity)
    if strides == 1 and input_channels == out_channels:
        x = tf.keras.layers.Add()([inputs, x])
    return x

def cbam_block(inputs):
    # Channel attention module
    avg_pool = GlobalAveragePooling2D()(inputs)
    max_pool = GlobalMaxPooling2D()(inputs)
    channel_features = Concatenate()([avg_pool, max_pool])
    channel_features = Dense(inputs.shape[-1] // 2, activation='relu')(channel_features)
    channel_att = Dense(inputs.shape[-1], activation='sigmoid')(channel_features)
    channel_att = Reshape((1, 1, inputs.shape[-1]))(channel_att)
    channel_att = Multiply()([inputs, channel_att])

    # Spatial attention module
    avg_pool = Lambda(lambda x: tf.keras.backend.mean(x, axis=3, keepdims=True))(channel_att)
    max_pool = Lambda(lambda x: tf.keras.backend.max(x, axis=3, keepdims=True))(channel_att)
    spatial_features = Concatenate()([avg_pool, max_pool])
    spatial_att = Conv2D(1, 3, padding='same', activation='sigmoid')(spatial_features)
    spatial_att = Multiply()([channel_att, spatial_att])

    return spatial_att

# Build EfficientNetB0 with CBAM
model_cbam = build_efficientnet_b0_cbam()

# %%
model_cbam.compile(optimizer=tf.keras.optimizers.legacy.Adam(
    learning_rate=0.0001),loss='categorical_crossentropy',metrics=['accuracy'])

model_cbam.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_7 (InputLayer)        [(None, 227, 227, 3)]        0         []
#
#  conv2d_128 (Conv2D)         (None, 114, 114, 32)         896       ['input_7[0][0]']
#
#  batch_normalization_128 (B  (None, 114, 114, 32)         128       ['conv2d_128[0][0]']
#  atchNormalization)
#
#  activation_91 (Activation)  (None, 114, 114, 32)         0         ['batch_normalization_128[0][0
#                                                                     ]']
#
#  conv2d_129 (Conv2D)         (None, 114, 114, 32)         1056      ['activation_91[0][0]']
#
#  batch_normalization_129 (B  (None, 114, 114, 32)         128       ['conv2d_129[0][0]']
#  atchNormalization)
#
#  activation_92 (Activation)  (None, 114, 114, 32)         0         ['batch_normalization_129[0][0
#                                                                     ]']
#
#  conv2d_130 (Conv2D)         (None, 114, 114, 32)         320       ['activation_92[0][0]']
#
#  batch_normalization_130 (B  (None, 114, 114, 32)         128       ['conv2d_130[0][0]']
#  atchNormalization)
#
#  activation_93 (Activation)  (None, 114, 114, 32)         0         ['batch_normalization_130[0][0
#                                                                     ]']
#
#  global_average_pooling2d_6  (None, 32)                   0         ['activation_93[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_4 (Gl  (None, 32)                   0         ['activation_93[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_3 (Concatenate  (None, 64)                   0         ['global_average_pooling2d_6[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling2d_4[0][0]
#                                                                     ']
#
#  dense_7 (Dense)             (None, 16)                   1040      ['concatenate_3[0][0]']
#
#  dense_8 (Dense)             (None, 32)                   544       ['dense_7[0][0]']
#
#  reshape_2 (Reshape)         (None, 1, 1, 32)             0         ['dense_8[0][0]']
#
#  multiply_1 (Multiply)       (None, 114, 114, 32)         0         ['activation_93[0][0]',
#                                                                      'reshape_2[0][0]']
#
#  lambda (Lambda)             (None, 114, 114, 1)          0         ['multiply_1[0][0]']
#
#  lambda_1 (Lambda)           (None, 114, 114, 1)          0         ['multiply_1[0][0]']
#
#  concatenate_4 (Concatenate  (None, 114, 114, 2)          0         ['lambda[0][0]',
#  )                                                                   'lambda_1[0][0]']
#
#  conv2d_131 (Conv2D)         (None, 114, 114, 1)          19        ['concatenate_4[0][0]']
#
#  multiply_2 (Multiply)       (None, 114, 114, 32)         0         ['multiply_1[0][0]',
#                                                                      'conv2d_131[0][0]']
#
#  conv2d_132 (Conv2D)         (None, 114, 114, 16)         528       ['multiply_2[0][0]']
#
#  batch_normalization_131 (B  (None, 114, 114, 16)         64        ['conv2d_132[0][0]']
#  atchNormalization)
#
#  conv2d_133 (Conv2D)         (None, 114, 114, 32)         544       ['batch_normalization_131[0][0
#                                                                     ]']
#
#  batch_normalization_132 (B  (None, 114, 114, 32)         128       ['conv2d_133[0][0]']
#  atchNormalization)
#
#  activation_94 (Activation)  (None, 114, 114, 32)         0         ['batch_normalization_132[0][0
#                                                                     ]']
#
#  conv2d_134 (Conv2D)         (None, 57, 57, 32)           320       ['activation_94[0][0]']
#
#  batch_normalization_133 (B  (None, 57, 57, 32)           128       ['conv2d_134[0][0]']
#  atchNormalization)
#
#  activation_95 (Activation)  (None, 57, 57, 32)           0         ['batch_normalization_133[0][0
#                                                                     ]']
#
#  global_average_pooling2d_7  (None, 32)                   0         ['activation_95[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_5 (Gl  (None, 32)                   0         ['activation_95[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_5 (Concatenate  (None, 64)                   0         ['global_average_pooling2d_7[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling2d_5[0][0]
#                                                                     ']
#
#  dense_9 (Dense)             (None, 16)                   1040      ['concatenate_5[0][0]']
#
#  dense_10 (Dense)            (None, 32)                   544       ['dense_9[0][0]']
#
#  reshape_3 (Reshape)         (None, 1, 1, 32)             0         ['dense_10[0][0]']
#
#  multiply_3 (Multiply)       (None, 57, 57, 32)           0         ['activation_95[0][0]',
#                                                                      'reshape_3[0][0]']
#
#  lambda_2 (Lambda)           (None, 57, 57, 1)            0         ['multiply_3[0][0]']
#
#  lambda_3 (Lambda)           (None, 57, 57, 1)            0         ['multiply_3[0][0]']
#
#  concatenate_6 (Concatenate  (None, 57, 57, 2)            0         ['lambda_2[0][0]',
#  )                                                                   'lambda_3[0][0]']
#
#  conv2d_135 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_6[0][0]']
#
#  multiply_4 (Multiply)       (None, 57, 57, 32)           0         ['multiply_3[0][0]',
#                                                                      'conv2d_135[0][0]']
#
#  conv2d_136 (Conv2D)         (None, 57, 57, 24)           792       ['multiply_4[0][0]']
#
#  batch_normalization_134 (B  (None, 57, 57, 24)           96        ['conv2d_136[0][0]']
#  atchNormalization)
#
#  conv2d_137 (Conv2D)         (None, 57, 57, 48)           1200      ['batch_normalization_134[0][0
#                                                                     ]']
#
#  batch_normalization_135 (B  (None, 57, 57, 48)           192       ['conv2d_137[0][0]']
#  atchNormalization)
#
#  activation_96 (Activation)  (None, 57, 57, 48)           0         ['batch_normalization_135[0][0
#                                                                     ]']
#
#  conv2d_138 (Conv2D)         (None, 57, 57, 48)           480       ['activation_96[0][0]']
#
#  batch_normalization_136 (B  (None, 57, 57, 48)           192       ['conv2d_138[0][0]']
#  atchNormalization)
#
#  activation_97 (Activation)  (None, 57, 57, 48)           0         ['batch_normalization_136[0][0
#                                                                     ]']
#
#  global_average_pooling2d_8  (None, 48)                   0         ['activation_97[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_6 (Gl  (None, 48)                   0         ['activation_97[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_7 (Concatenate  (None, 96)                   0         ['global_average_pooling2d_8[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling2d_6[0][0]
#                                                                     ']
#
#  dense_11 (Dense)            (None, 24)                   2328      ['concatenate_7[0][0]']
#
#  dense_12 (Dense)            (None, 48)                   1200      ['dense_11[0][0]']
#
#  reshape_4 (Reshape)         (None, 1, 1, 48)             0         ['dense_12[0][0]']
#
#  multiply_5 (Multiply)       (None, 57, 57, 48)           0         ['activation_97[0][0]',
#                                                                      'reshape_4[0][0]']
#
#  lambda_4 (Lambda)           (None, 57, 57, 1)            0         ['multiply_5[0][0]']
#
#  lambda_5 (Lambda)           (None, 57, 57, 1)            0         ['multiply_5[0][0]']
#
#  concatenate_8 (Concatenate  (None, 57, 57, 2)            0         ['lambda_4[0][0]',
#  )                                                                   'lambda_5[0][0]']
#
#  conv2d_139 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_8[0][0]']
#
#  multiply_6 (Multiply)       (None, 57, 57, 48)           0         ['multiply_5[0][0]',
#                                                                      'conv2d_139[0][0]']
#
#  conv2d_140 (Conv2D)         (None, 57, 57, 24)           1176      ['multiply_6[0][0]']
#
#  batch_normalization_137 (B  (None, 57, 57, 24)           96        ['conv2d_140[0][0]']
#  atchNormalization)
#
#  add_30 (Add)                (None, 57, 57, 24)           0         ['batch_normalization_134[0][0
#                                                                     ]',
#                                                                      'batch_normalization_137[0][0
#                                                                     ]']
#
#  conv2d_141 (Conv2D)         (None, 57, 57, 48)           1200      ['add_30[0][0]']
#
#  batch_normalization_138 (B  (None, 57, 57, 48)           192       ['conv2d_141[0][0]']
#  atchNormalization)
#
#  activation_98 (Activation)  (None, 57, 57, 48)           0         ['batch_normalization_138[0][0
#                                                                     ]']
#
#  conv2d_142 (Conv2D)         (None, 57, 57, 48)           480       ['activation_98[0][0]']
#
#  batch_normalization_139 (B  (None, 57, 57, 48)           192       ['conv2d_142[0][0]']
#  atchNormalization)
#
#  activation_99 (Activation)  (None, 57, 57, 48)           0         ['batch_normalization_139[0][0
#                                                                     ]']
#
#  global_average_pooling2d_9  (None, 48)                   0         ['activation_99[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_max_pooling2d_7 (Gl  (None, 48)                   0         ['activation_99[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_9 (Concatenate  (None, 96)                   0         ['global_average_pooling2d_9[0
#  )                                                                  ][0]',
#                                                                      'global_max_pooling2d_7[0][0]
#                                                                     ']
#
#  dense_13 (Dense)            (None, 24)                   2328      ['concatenate_9[0][0]']
#
#  dense_14 (Dense)            (None, 48)                   1200      ['dense_13[0][0]']
#
#  reshape_5 (Reshape)         (None, 1, 1, 48)             0         ['dense_14[0][0]']
#
#  multiply_7 (Multiply)       (None, 57, 57, 48)           0         ['activation_99[0][0]',
#                                                                      'reshape_5[0][0]']
#
#  lambda_6 (Lambda)           (None, 57, 57, 1)            0         ['multiply_7[0][0]']
#
#  lambda_7 (Lambda)           (None, 57, 57, 1)            0         ['multiply_7[0][0]']
#
#  concatenate_10 (Concatenat  (None, 57, 57, 2)            0         ['lambda_6[0][0]',
#  e)                                                                  'lambda_7[0][0]']
#
#  conv2d_143 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_10[0][0]']
#
#  multiply_8 (Multiply)       (None, 57, 57, 48)           0         ['multiply_7[0][0]',
#                                                                      'conv2d_143[0][0]']
#
#  conv2d_144 (Conv2D)         (None, 57, 57, 24)           1176      ['multiply_8[0][0]']
#
#  batch_normalization_140 (B  (None, 57, 57, 24)           96        ['conv2d_144[0][0]']
#  atchNormalization)
#
#  add_31 (Add)                (None, 57, 57, 24)           0         ['add_30[0][0]',
#                                                                      'batch_normalization_140[0][0
#                                                                     ]']
#
#  conv2d_145 (Conv2D)         (None, 57, 57, 48)           1200      ['add_31[0][0]']
#
#  batch_normalization_141 (B  (None, 57, 57, 48)           192       ['conv2d_145[0][0]']
#  atchNormalization)
#
#  activation_100 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_141[0][0
#  )                                                                  ]']
#
#  conv2d_146 (Conv2D)         (None, 57, 57, 48)           480       ['activation_100[0][0]']
#
#  batch_normalization_142 (B  (None, 57, 57, 48)           192       ['conv2d_146[0][0]']
#  atchNormalization)
#
#  activation_101 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_142[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_1  (None, 48)                   0         ['activation_101[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_8 (Gl  (None, 48)                   0         ['activation_101[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_11 (Concatenat  (None, 96)                   0         ['global_average_pooling2d_10[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_8[0][0]
#                                                                     ']
#
#  dense_15 (Dense)            (None, 24)                   2328      ['concatenate_11[0][0]']
#
#  dense_16 (Dense)            (None, 48)                   1200      ['dense_15[0][0]']
#
#  reshape_6 (Reshape)         (None, 1, 1, 48)             0         ['dense_16[0][0]']
#
#  multiply_9 (Multiply)       (None, 57, 57, 48)           0         ['activation_101[0][0]',
#                                                                      'reshape_6[0][0]']
#
#  lambda_8 (Lambda)           (None, 57, 57, 1)            0         ['multiply_9[0][0]']
#
#  lambda_9 (Lambda)           (None, 57, 57, 1)            0         ['multiply_9[0][0]']
#
#  concatenate_12 (Concatenat  (None, 57, 57, 2)            0         ['lambda_8[0][0]',
#  e)                                                                  'lambda_9[0][0]']
#
#  conv2d_147 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_12[0][0]']
#
#  multiply_10 (Multiply)      (None, 57, 57, 48)           0         ['multiply_9[0][0]',
#                                                                      'conv2d_147[0][0]']
#
#  conv2d_148 (Conv2D)         (None, 57, 57, 24)           1176      ['multiply_10[0][0]']
#
#  batch_normalization_143 (B  (None, 57, 57, 24)           96        ['conv2d_148[0][0]']
#  atchNormalization)
#
#  add_32 (Add)                (None, 57, 57, 24)           0         ['add_31[0][0]',
#                                                                      'batch_normalization_143[0][0
#                                                                     ]']
#
#  conv2d_149 (Conv2D)         (None, 57, 57, 48)           1200      ['add_32[0][0]']
#
#  batch_normalization_144 (B  (None, 57, 57, 48)           192       ['conv2d_149[0][0]']
#  atchNormalization)
#
#  activation_102 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_144[0][0
#  )                                                                  ]']
#
#  conv2d_150 (Conv2D)         (None, 57, 57, 48)           480       ['activation_102[0][0]']
#
#  batch_normalization_145 (B  (None, 57, 57, 48)           192       ['conv2d_150[0][0]']
#  atchNormalization)
#
#  activation_103 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_145[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_1  (None, 48)                   0         ['activation_103[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_9 (Gl  (None, 48)                   0         ['activation_103[0][0]']
#  obalMaxPooling2D)
#
#  concatenate_13 (Concatenat  (None, 96)                   0         ['global_average_pooling2d_11[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_9[0][0]
#                                                                     ']
#
#  dense_17 (Dense)            (None, 24)                   2328      ['concatenate_13[0][0]']
#
#  dense_18 (Dense)            (None, 48)                   1200      ['dense_17[0][0]']
#
#  reshape_7 (Reshape)         (None, 1, 1, 48)             0         ['dense_18[0][0]']
#
#  multiply_11 (Multiply)      (None, 57, 57, 48)           0         ['activation_103[0][0]',
#                                                                      'reshape_7[0][0]']
#
#  lambda_10 (Lambda)          (None, 57, 57, 1)            0         ['multiply_11[0][0]']
#
#  lambda_11 (Lambda)          (None, 57, 57, 1)            0         ['multiply_11[0][0]']
#
#  concatenate_14 (Concatenat  (None, 57, 57, 2)            0         ['lambda_10[0][0]',
#  e)                                                                  'lambda_11[0][0]']
#
#  conv2d_151 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_14[0][0]']
#
#  multiply_12 (Multiply)      (None, 57, 57, 48)           0         ['multiply_11[0][0]',
#                                                                      'conv2d_151[0][0]']
#
#  conv2d_152 (Conv2D)         (None, 57, 57, 24)           1176      ['multiply_12[0][0]']
#
#  batch_normalization_146 (B  (None, 57, 57, 24)           96        ['conv2d_152[0][0]']
#  atchNormalization)
#
#  add_33 (Add)                (None, 57, 57, 24)           0         ['add_32[0][0]',
#                                                                      'batch_normalization_146[0][0
#                                                                     ]']
#
#  conv2d_153 (Conv2D)         (None, 57, 57, 48)           1200      ['add_33[0][0]']
#
#  batch_normalization_147 (B  (None, 57, 57, 48)           192       ['conv2d_153[0][0]']
#  atchNormalization)
#
#  activation_104 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_147[0][0
#  )                                                                  ]']
#
#  conv2d_154 (Conv2D)         (None, 57, 57, 48)           480       ['activation_104[0][0]']
#
#  batch_normalization_148 (B  (None, 57, 57, 48)           192       ['conv2d_154[0][0]']
#  atchNormalization)
#
#  activation_105 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_148[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_1  (None, 48)                   0         ['activation_105[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_10 (G  (None, 48)                   0         ['activation_105[0][0]']
#  lobalMaxPooling2D)
#
#  concatenate_15 (Concatenat  (None, 96)                   0         ['global_average_pooling2d_12[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_10[0][0
#                                                                     ]']
#
#  dense_19 (Dense)            (None, 24)                   2328      ['concatenate_15[0][0]']
#
#  dense_20 (Dense)            (None, 48)                   1200      ['dense_19[0][0]']
#
#  reshape_8 (Reshape)         (None, 1, 1, 48)             0         ['dense_20[0][0]']
#
#  multiply_13 (Multiply)      (None, 57, 57, 48)           0         ['activation_105[0][0]',
#                                                                      'reshape_8[0][0]']
#
#  lambda_12 (Lambda)          (None, 57, 57, 1)            0         ['multiply_13[0][0]']
#
#  lambda_13 (Lambda)          (None, 57, 57, 1)            0         ['multiply_13[0][0]']
#
#  concatenate_16 (Concatenat  (None, 57, 57, 2)            0         ['lambda_12[0][0]',
#  e)                                                                  'lambda_13[0][0]']
#
#  conv2d_155 (Conv2D)         (None, 57, 57, 1)            19        ['concatenate_16[0][0]']
#
#  multiply_14 (Multiply)      (None, 57, 57, 48)           0         ['multiply_13[0][0]',
#                                                                      'conv2d_155[0][0]']
#
#  conv2d_156 (Conv2D)         (None, 57, 57, 24)           1176      ['multiply_14[0][0]']
#
#  batch_normalization_149 (B  (None, 57, 57, 24)           96        ['conv2d_156[0][0]']
#  atchNormalization)
#
#  add_34 (Add)                (None, 57, 57, 24)           0         ['add_33[0][0]',
#                                                                      'batch_normalization_149[0][0
#                                                                     ]']
#
#  conv2d_157 (Conv2D)         (None, 57, 57, 48)           1200      ['add_34[0][0]']
#
#  batch_normalization_150 (B  (None, 57, 57, 48)           192       ['conv2d_157[0][0]']
#  atchNormalization)
#
#  activation_106 (Activation  (None, 57, 57, 48)           0         ['batch_normalization_150[0][0
#  )                                                                  ]']
#
#  conv2d_158 (Conv2D)         (None, 29, 29, 48)           480       ['activation_106[0][0]']
#
#  batch_normalization_151 (B  (None, 29, 29, 48)           192       ['conv2d_158[0][0]']
#  atchNormalization)
#
#  activation_107 (Activation  (None, 29, 29, 48)           0         ['batch_normalization_151[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_1  (None, 48)                   0         ['activation_107[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_11 (G  (None, 48)                   0         ['activation_107[0][0]']
#  lobalMaxPooling2D)
#
#  concatenate_17 (Concatenat  (None, 96)                   0         ['global_average_pooling2d_13[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_11[0][0
#                                                                     ]']
#
#  dense_21 (Dense)            (None, 24)                   2328      ['concatenate_17[0][0]']
#
#  dense_22 (Dense)            (None, 48)                   1200      ['dense_21[0][0]']
#
#  reshape_9 (Reshape)         (None, 1, 1, 48)             0         ['dense_22[0][0]']
#
#  multiply_15 (Multiply)      (None, 29, 29, 48)           0         ['activation_107[0][0]',
#                                                                      'reshape_9[0][0]']
#
#  lambda_14 (Lambda)          (None, 29, 29, 1)            0         ['multiply_15[0][0]']
#
#  lambda_15 (Lambda)          (None, 29, 29, 1)            0         ['multiply_15[0][0]']
#
#  concatenate_18 (Concatenat  (None, 29, 29, 2)            0         ['lambda_14[0][0]',
#  e)                                                                  'lambda_15[0][0]']
#
#  conv2d_159 (Conv2D)         (None, 29, 29, 1)            19        ['concatenate_18[0][0]']
#
#  multiply_16 (Multiply)      (None, 29, 29, 48)           0         ['multiply_15[0][0]',
#                                                                      'conv2d_159[0][0]']
#
#  conv2d_160 (Conv2D)         (None, 29, 29, 40)           1960      ['multiply_16[0][0]']
#
#  batch_normalization_152 (B  (None, 29, 29, 40)           160       ['conv2d_160[0][0]']
#  atchNormalization)
#
#  conv2d_161 (Conv2D)         (None, 29, 29, 80)           3280      ['batch_normalization_152[0][0
#                                                                     ]']
#
#  batch_normalization_153 (B  (None, 29, 29, 80)           320       ['conv2d_161[0][0]']
#  atchNormalization)
#
#  activation_108 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_153[0][0
#  )                                                                  ]']
#
#  conv2d_162 (Conv2D)         (None, 29, 29, 80)           800       ['activation_108[0][0]']
#
#  batch_normalization_154 (B  (None, 29, 29, 80)           320       ['conv2d_162[0][0]']
#  atchNormalization)
#
#  activation_109 (Activation  (None, 29, 29, 80)           0         ['batch_normalization_154[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_1  (None, 80)                   0         ['activation_109[0][0]']
#  4 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_12 (G  (None, 80)                   0         ['activation_109[0][0]']
#  lobalMaxPooling2D)
#
#  concatenate_19 (Concatenat  (None, 160)                  0         ['global_average_pooling2d_14[
# ...
#  dense_75 (Dense)            (None, 160)                  102560    ['concatenate_71[0][0]']
#
#  dense_76 (Dense)            (None, 320)                  51520     ['dense_75[0][0]']
#
#  reshape_36 (Reshape)        (None, 1, 1, 320)            0         ['dense_76[0][0]']
#
#  multiply_69 (Multiply)      (None, 8, 8, 320)            0         ['activation_161[0][0]',
#                                                                      'reshape_36[0][0]']
#
#  lambda_68 (Lambda)          (None, 8, 8, 1)              0         ['multiply_69[0][0]']
#
#  lambda_69 (Lambda)          (None, 8, 8, 1)              0         ['multiply_69[0][0]']
#
#  concatenate_72 (Concatenat  (None, 8, 8, 2)              0         ['lambda_68[0][0]',
#  e)                                                                  'lambda_69[0][0]']
#
#  conv2d_267 (Conv2D)         (None, 8, 8, 1)              19        ['concatenate_72[0][0]']
#
#  multiply_70 (Multiply)      (None, 8, 8, 320)            0         ['multiply_69[0][0]',
#                                                                      'conv2d_267[0][0]']
#
#  conv2d_268 (Conv2D)         (None, 8, 8, 320)            102720    ['multiply_70[0][0]']
#
#  batch_normalization_233 (B  (None, 8, 8, 320)            1280      ['conv2d_268[0][0]']
#  atchNormalization)
#
#  add_57 (Add)                (None, 8, 8, 320)            0         ['add_56[0][0]',
#                                                                      'batch_normalization_233[0][0
#                                                                     ]']
#
#  conv2d_269 (Conv2D)         (None, 8, 8, 320)            102720    ['add_57[0][0]']
#
#  batch_normalization_234 (B  (None, 8, 8, 320)            1280      ['conv2d_269[0][0]']
#  atchNormalization)
#
#  activation_162 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  conv2d_270 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_162[0][0]']
#
#  batch_normalization_235 (B  (None, 8, 8, 320)            1280      ['conv2d_270[0][0]']
#  atchNormalization)
#
#  activation_163 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_4  (None, 320)                  0         ['activation_163[0][0]']
#  1 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_39 (G  (None, 320)                  0         ['activation_163[0][0]']
#  lobalMaxPooling2D)
#
#  concatenate_73 (Concatenat  (None, 640)                  0         ['global_average_pooling2d_41[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_39[0][0
#                                                                     ]']
#
#  dense_77 (Dense)            (None, 160)                  102560    ['concatenate_73[0][0]']
#
#  dense_78 (Dense)            (None, 320)                  51520     ['dense_77[0][0]']
#
#  reshape_37 (Reshape)        (None, 1, 1, 320)            0         ['dense_78[0][0]']
#
#  multiply_71 (Multiply)      (None, 8, 8, 320)            0         ['activation_163[0][0]',
#                                                                      'reshape_37[0][0]']
#
#  lambda_70 (Lambda)          (None, 8, 8, 1)              0         ['multiply_71[0][0]']
#
#  lambda_71 (Lambda)          (None, 8, 8, 1)              0         ['multiply_71[0][0]']
#
#  concatenate_74 (Concatenat  (None, 8, 8, 2)              0         ['lambda_70[0][0]',
#  e)                                                                  'lambda_71[0][0]']
#
#  conv2d_271 (Conv2D)         (None, 8, 8, 1)              19        ['concatenate_74[0][0]']
#
#  multiply_72 (Multiply)      (None, 8, 8, 320)            0         ['multiply_71[0][0]',
#                                                                      'conv2d_271[0][0]']
#
#  conv2d_272 (Conv2D)         (None, 8, 8, 320)            102720    ['multiply_72[0][0]']
#
#  batch_normalization_236 (B  (None, 8, 8, 320)            1280      ['conv2d_272[0][0]']
#  atchNormalization)
#
#  add_58 (Add)                (None, 8, 8, 320)            0         ['add_57[0][0]',
#                                                                      'batch_normalization_236[0][0
#                                                                     ]']
#
#  conv2d_273 (Conv2D)         (None, 8, 8, 320)            102720    ['add_58[0][0]']
#
#  batch_normalization_237 (B  (None, 8, 8, 320)            1280      ['conv2d_273[0][0]']
#  atchNormalization)
#
#  activation_164 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  conv2d_274 (Conv2D)         (None, 8, 8, 320)            3200      ['activation_164[0][0]']
#
#  batch_normalization_238 (B  (None, 8, 8, 320)            1280      ['conv2d_274[0][0]']
#  atchNormalization)
#
#  activation_165 (Activation  (None, 8, 8, 320)            0         ['batch_normalization_238[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_4  (None, 320)                  0         ['activation_165[0][0]']
#  2 (GlobalAveragePooling2D)
#
#  global_max_pooling2d_40 (G  (None, 320)                  0         ['activation_165[0][0]']
#  lobalMaxPooling2D)
#
#  concatenate_75 (Concatenat  (None, 640)                  0         ['global_average_pooling2d_42[
#  e)                                                                 0][0]',
#                                                                      'global_max_pooling2d_40[0][0
#                                                                     ]']
#
#  dense_79 (Dense)            (None, 160)                  102560    ['concatenate_75[0][0]']
#
#  dense_80 (Dense)            (None, 320)                  51520     ['dense_79[0][0]']
#
#  reshape_38 (Reshape)        (None, 1, 1, 320)            0         ['dense_80[0][0]']
#
#  multiply_73 (Multiply)      (None, 8, 8, 320)            0         ['activation_165[0][0]',
#                                                                      'reshape_38[0][0]']
#
#  lambda_72 (Lambda)          (None, 8, 8, 1)              0         ['multiply_73[0][0]']
#
#  lambda_73 (Lambda)          (None, 8, 8, 1)              0         ['multiply_73[0][0]']
#
#  concatenate_76 (Concatenat  (None, 8, 8, 2)              0         ['lambda_72[0][0]',
#  e)                                                                  'lambda_73[0][0]']
#
#  conv2d_275 (Conv2D)         (None, 8, 8, 1)              19        ['concatenate_76[0][0]']
#
#  multiply_74 (Multiply)      (None, 8, 8, 320)            0         ['multiply_73[0][0]',
#                                                                      'conv2d_275[0][0]']
#
#  conv2d_276 (Conv2D)         (None, 8, 8, 320)            102720    ['multiply_74[0][0]']
#
#  batch_normalization_239 (B  (None, 8, 8, 320)            1280      ['conv2d_276[0][0]']
#  atchNormalization)
#
#  add_59 (Add)                (None, 8, 8, 320)            0         ['add_58[0][0]',
#                                                                      'batch_normalization_239[0][0
#                                                                     ]']
#
#  conv2d_277 (Conv2D)         (None, 8, 8, 1280)           410880    ['add_59[0][0]']
#
#  batch_normalization_240 (B  (None, 8, 8, 1280)           5120      ['conv2d_277[0][0]']
#  atchNormalization)
#
#  activation_166 (Activation  (None, 8, 8, 1280)           0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  global_average_pooling2d_4  (None, 1280)                 0         ['activation_166[0][0]']
#  3 (GlobalAveragePooling2D)
#
#  dense_81 (Dense)            (None, 38)                   48678     ['global_average_pooling2d_43[
#                                                                     0][0]']
#
# ==================================================================================================
# Total params: 11113825 (42.40 MB)
# Trainable params: 11061665 (42.20 MB)
# Non-trainable params: 52160 (203.75 KB)
# __________________________________________________________________________________________________

# %%
training_history = model.fit(x=training_set,validation_data=validation_set,epochs=10)
# Out:
# Epoch 1/10
# 2024-05-02 01:20:11.278892: I external/local_xla/xla/service/service.cc:168] XLA service 0x11ab0dc00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2024-05-02 01:20:11.279491: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1714593011.470288       1 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2024-05-02 01:20:11.471341: E external/local_xla/xla/stream_executor/stream_executor_internal.h:177] SetPriority unimplemented for this stream.
#   1/661 [..............................] - ETA: 4:58:13 - loss: 3.8060 - accuracy: 0.1094
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 training_history = model.fit(x=training_set,validation_data=validation_set,epochs=10)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/keras/src/engine/training.py:1807, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1799 with tf.profiler.experimental.Trace(
#    1800     "train",
#    1801     epoch_num=epoch,
#    (...)
#    1804     _r=1,
#    1805 ):
#    1806     callbacks.on_train_batch_begin(step)
# -> 1807     tmp_logs = self.train_function(iterator)
#    1808     if data_handler.should_sync:
#    1809         context.async_wait()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:832, in Function.__call__(self, *args, **kwds)
#     829 compiler = "xla" if self._jit_compile else "nonXla"
#     831 with OptionalXlaContext(self._jit_compile):
# --> 832   result = self._call(*args, **kwds)
#     834 new_tracing_count = self.experimental_get_tracing_count()
#     835 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:868, in Function._call(self, *args, **kwds)
#     865   self._lock.release()
#     866   # In this case we have created variables on the first call, so we run the
#     867   # defunned version which is guaranteed to never create variables.
# --> 868   return tracing_compilation.call_function(
#     869       args, kwds, self._no_variable_creation_config
#     870   )
#     871 elif self._variable_creation_config is not None:
#     872   # Release the lock early so that multiple threads can perform the call
#     873   # in parallel.
#     874   self._lock.release()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1323, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1319 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1320 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1321     and executing_eagerly):
#    1322   # No tape is watching; skip to running the function.
# -> 1323   return self._inference_function.call_preflattened(args)
#    1324 forward_backward = self._select_forward_and_backward_functions(
#    1325     args,
#    1326     possible_gradient_type,
#    1327     executing_eagerly)
#    1328 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/context.py:1486, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1484 cancellation_context = cancellation.context()
#    1485 if cancellation_context is None:
# -> 1486   outputs = execute.execute(
#    1487       name.decode("utf-8"),
#    1488       num_outputs=num_outputs,
#    1489       inputs=tensor_inputs,
#    1490       attrs=attrs,
#    1491       ctx=self,
#    1492   )
#    1493 else:
#    1494   outputs = execute.execute_with_cancellation(
#    1495       name.decode("utf-8"),
#    1496       num_outputs=num_outputs,
#    (...)
#    1500       cancellation_manager=cancellation_context,
#    1501   )
#
# File ~/anaconda3/envs/tensorflow/lib/python3.11/site-packages/tensorflow/python/eager/execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
#Training set Accuracy
train_loss, train_acc = model.evaluate(training_set)
print('Training accuracy:', train_acc)

#Validation set Accuracy
val_loss, val_acc = model.evaluate(validation_set)
print('Validation accuracy:', val_acc)

model.save('efficientnet_cbam.keras')
